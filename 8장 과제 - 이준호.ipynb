# %% [markdown]
# # 8장 모듈과 활용 실습

# %% [markdown]
# ## LAB 8-1: 오늘의 날짜와 현재 시간 출력하기

# %%
import datetime as dt

now = dt.datetime.now()
today = dt.date.today()

if now.hour < 12:
    am_pm = '오전'
    hour = now.hour
else:
    am_pm = '오후'
    hour = now.hour - 12

if hour == 0:
    hour = 12

print(f'오늘의 날짜 : {today.year}년 {today.month}월 {today.day}일')
print(f'현재시간 : {am_pm} {hour}시 {now.minute}분 {now.second}초')
# Out:
# 오늘의 날짜 : 2026년 5월 3일
# 현재시간 : 오전 12시 48분 57초

# %% [markdown]
# ## LAB 8-2: 남은 날짜 계산하기

# %%
import datetime as dt

today = dt.date.today()
print(f'오늘은 {today.year}년 {today.month}월 {today.day}일입니다.')

xMas = dt.datetime(2027, 12, 25)
gap = xMas - dt.datetime.now()
print(f'2027년 크리스마스 까지는 {gap.days}일 {gap.seconds // 3600}시간 남았습니다.')

new_year = dt.datetime(2036, 1, 1)
gap = new_year - dt.datetime.now()
print(f'2036년 새해 까지는 {gap.days}일 {gap.seconds // 3600}시간 남았습니다.')

# 자신의 생일에 맞게 월과 일을 수정한다.
birthday = dt.datetime(today.year, 8, 29)
if birthday < dt.datetime.now():
    birthday = dt.datetime(today.year + 1, 8, 29)
gap = birthday - dt.datetime.now()
print(f'{birthday.year}년 생일까지는 {gap.days}일 {gap.seconds // 3600}시간 남았습니다.')
# Out:
# 오늘은 2026년 5월 3일입니다.
# 2027년 크리스마스 까지는 600일 23시간 남았습니다.
# 2036년 새해 까지는 3529일 23시간 남았습니다.
# 2026년 생일까지는 117일 23시간 남았습니다.

# %% [markdown]
# ## LAB 8-3: 날짜 계산하기

# %%
import datetime as dt

# 1. 오늘 날짜로부터 1,000일 후의 날짜
today = dt.datetime.now()
thousand = dt.timedelta(days=1000)
plus1000day = today + thousand
print('오늘 =', today)
print('1,000일 후 =', plus1000day)

# 2. 처음 사귄 날짜를 입력받아 100일 기념일 출력
start_text = input('처음으로 사귄 연도와 월, 일을 입력하시오 : ')
year, month, day = map(int, start_text.split())
start_day = dt.datetime(year, month, day)
hundred = dt.timedelta(days=99)
anniversary = start_day + hundred
print(f'100일 기념일은 : {anniversary.year}년 {anniversary.month}월 {anniversary.day}일입니다.')
# Out:
# 오늘 = 2026-05-03 00:48:57.643131
# 1,000일 후 = 2029-01-27 00:48:57.643131
# 100일 기념일은 : 2025년 8월 17일입니다.

# %% [markdown]
# ## LAB 8-4: math 모듈을 이용한 계산

# %%
import math as m

for n in range(2, 11):
    print('4**{} = {:.1f}'.format(n, m.pow(4, n)))

print()
for degree in range(0, 181, 10):
    radian = m.radians(degree)
    print('{:3d} degree = {:.3f} radian'.format(degree, radian))

print()
for degree in range(0, 181, 10):
    print('sin({:3d}) = {:.2f}'.format(degree, m.sin(m.radians(degree))))
# Out:
# 4**2 = 16.0
# 4**3 = 64.0
# 4**4 = 256.0
# 4**5 = 1024.0
# 4**6 = 4096.0
# 4**7 = 16384.0
# 4**8 = 65536.0
# 4**9 = 262144.0
# 4**10 = 1048576.0
#
#   0 degree = 0.000 radian
#  10 degree = 0.175 radian
#  20 degree = 0.349 radian
#  30 degree = 0.524 radian
#  40 degree = 0.698 radian
#  50 degree = 0.873 radian
#  60 degree = 1.047 radian
#  70 degree = 1.222 radian
#  80 degree = 1.396 radian
#  90 degree = 1.571 radian
# 100 degree = 1.745 radian
# 110 degree = 1.920 radian
# 120 degree = 2.094 radian
# 130 degree = 2.269 radian
# 140 degree = 2.443 radian
# 150 degree = 2.618 radian
# 160 degree = 2.793 radian
# 170 degree = 2.967 radian
# 180 degree = 3.142 radian
#
# sin(  0) = 0.00
# sin( 10) = 0.17
# sin( 20) = 0.34
# sin( 30) = 0.50
# sin( 40) = 0.64
# sin( 50) = 0.77
# sin( 60) = 0.87
# sin( 70) = 0.94
# sin( 80) = 0.98
# sin( 90) = 1.00
# sin(100) = 0.98
# sin(110) = 0.94
# sin(120) = 0.87
# sin(130) = 0.77
# sin(140) = 0.64
# sin(150) = 0.50
# sin(160) = 0.34
# sin(170) = 0.17
# sin(180) = 0.00

# %% [markdown]
# ## LAB 8-5: 랜덤 번호 생성기

# %%
import random as rd

num_list = []
for _ in range(3):
    num_list.append(rd.randrange(0, 101, 5))
print('0에서 100 이하의 정수 중에서 5의 배수', num_list)

num_list = list(range(1, 11))
num_list = rd.sample(num_list, 3)
print('1에서 10 사이의 임의의 정수 :', num_list)
# Out:
# 0에서 100 이하의 정수 중에서 5의 배수 [60, 75, 85]
# 1에서 10 사이의 임의의 정수 : [6, 1, 2]

# %% [markdown]
# ## LAB 8-6: 로또 번호 얻기

# %%
import random as rd

print('이번 주의 추천 로또 번호')
for _ in range(5):
    lotto_list = list(range(1, 46))       # 1부터 45까지 생성
    lotto_list = rd.sample(lotto_list, 6) # 임의의 값 6개 추출
    lotto_list.sort()                     # 선택된 번호를 정렬
    print(lotto_list)

lotto_list = list(range(1, 46))
winning = rd.sample(lotto_list, 6)
winning.sort()

bonus_list = [num for num in lotto_list if num not in winning]
bonus = rd.sample(bonus_list, 1)
print()
print('이번 주의 당첨 로또 번호 + 보너스')
print(winning, '+', bonus)
# Out:
# 이번 주의 추천 로또 번호
# [23, 28, 32, 33, 36, 37]
# [3, 11, 19, 35, 36, 38]
# [5, 22, 28, 33, 37, 44]
# [2, 13, 22, 30, 34, 36]
# [2, 3, 15, 25, 28, 43]
#
# 이번 주의 당첨 로또 번호 + 보너스
# [2, 15, 17, 23, 44, 45] + [28]

# %% [markdown]
# ## 연습문제 8.1: 연애 시작일과 기념일 계산

# %%
import datetime as dt

start_day = dt.date(2019, 2, 14)
today = dt.date.today()
gap = today - start_day

print(f'춘향이와 몽룡이의 연애 시작일 : {start_day.year}년 {start_day.month}월 {start_day.day}일')
print(f'연애 시작일로부터 경과한 날짜 : {gap.days}일')

for day in [100, 200, 500, 1000]:
    anniversary = start_day + dt.timedelta(days=day)
    print(f'{day:,}일 기념일 : {anniversary.year}년 {anniversary.month}월 {anniversary.day}일')
# Out:
# 춘향이와 몽룡이의 연애 시작일 : 2019년 2월 14일
# 연애 시작일로부터 경과한 날짜 : 2635일
# 100일 기념일 : 2019년 5월 25일
# 200일 기념일 : 2019년 9월 2일
# 500일 기념일 : 2020년 6월 28일
# 1,000일 기념일 : 2021년 11월 10일

# %% [markdown]
# ## 연습문제 8.2: 1부터 1,000,000까지의 합과 실행 시간

# %%
import time


def sum1to1000000():
    result = 0
    for i in range(1, 1000001):
        result = result + i
    return result

start_time = time.time()              # 시작 시간을 기록
sum1to1000000()
end_time = time.time()                # 종료 시간을 기록
gap = end_time - start_time
print('1에서 1,000,000까지의 합을 구하는 시간 : {:7.4f}초'.format(gap))

start_time = time.time()
for _ in range(100):
    sum1to1000000()
end_time = time.time()
gap = end_time - start_time
print('1,000,000까지의 합을 100번 반복해서 구하는 시간 : {:7.4f}초'.format(gap))
# Out:
# 1에서 1,000,000까지의 합을 구하는 시간 :  0.0253초
# 1,000,000까지의 합을 100번 반복해서 구하는 시간 :  2.4026초

# %% [markdown]
# ## 연습문제 8.3: 여러 함수의 100회 반복 실행 시간 측정

# %%
import time
import math as m
import contextlib
import io


def hello_python():
    print('Hello Python!')


def factorial_10000():
    result = 1
    for i in range(1, 10001):
        result = result * i
    return result


def odd_cube_sum():
    result = 0
    for i in range(1, 10001, 2):
        result = result + i ** 3
    return result


def sin_sum():
    result = 0
    for degree in range(1, 361):
        result = result + m.sin(m.radians(degree))
    return result


def check_time(func):
    start_time = time.time()
    for _ in range(100):
        func()
    end_time = time.time()
    return end_time - start_time

with contextlib.redirect_stdout(io.StringIO()):
    gap = check_time(hello_python)
print('Hello Python! 출력을 100번 반복하는 시간 : {:7.4f}초'.format(gap))

print('10000!을 100번 반복해서 구하는 시간 : {:7.4f}초'.format(check_time(factorial_10000)))
print('1에서 10000까지 홀수의 세제곱 더하기를 100번 반복하는 시간 : {:7.4f}초'.format(check_time(odd_cube_sum)))
print('1에서 360도까지 sin 값의 합을 100번 반복하는 시간 : {:7.4f}초'.format(check_time(sin_sum)))
# Out:
# Hello Python! 출력을 100번 반복하는 시간 :  0.0000초
# 10000!을 100번 반복해서 구하는 시간 :  1.7754초
# 1에서 10000까지 홀수의 세제곱 더하기를 100번 반복하는 시간 :  0.0221초
# 1에서 360도까지 sin 값의 합을 100번 반복하는 시간 :  0.0031초

# %% [markdown]
# ## 연습문제 8.4: 의사난수 함수 만들기

# %%
import time


def my_rand(x):
    new_x = (1103515245 * x + 12345) % (2 ** 31)
    return new_x

# 1. 하나의 시드에서 연속적으로 10개의 의사난수 출력
x = 1234
for _ in range(10):
    x = my_rand(x)
    print(x % 1000001)

print()

# 2. time()으로 만든 시드를 이용해 5개의 난수를 2번 출력
x = int(time.time())
for _ in range(2):
    for _ in range(5):
        x = my_rand(x)
        print(x % 1000001)
    print()
# Out:
# 191610
# 476192
# 706756
# 984733
# 904870
# 66822
# 527339
# 140008
# 867913
# 848660
#
# 392496
# 325425
# 316874
# 563848
# 683355
#
# 277740
# 373149
# 607112
# 193399
# 130642
